# %% [markdown]
# <a href="https://colab.research.google.com/github/PeiHui369/Back-End-Development-and-APIs/blob/main/HousePricePrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline
df = pd.read_csv("House Pricing.csv")
df.head()
mapping = {'yes': 1.0, 'no': 0.0}
mappingf = {'furnished': 1.0, 'semi-furnished': 0.5, 'unfurnished':0.0}

# Apply the mapping to the column
df['mainroad'] = df['mainroad'].map(mapping).astype(float)
df['guestroom'] = df['guestroom'].map(mapping).astype(float)
df['basement'] = df['basement'].map(mapping).astype(float)
df['hotwaterheating'] = df['hotwaterheating'].map(mapping).astype(float)
df['airconditioning'] = df['airconditioning'].map(mapping).astype(float)
df['prefarea'] = df['prefarea'].map(mapping).astype(float)
df['furnishingstatus'] = df['furnishingstatus'].map(mappingf).astype(float)

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#          mainroad   guestroom    basement  hotwaterheating  airconditioning  \
# count  545.000000  545.000000  545.000000       545.000000       545.000000
# mean     0.858716    0.177982    0.350459         0.045872         0.315596
# std      0.348635    0.382849    0.477552         0.209399         0.465180
# ...

# %%
plt.scatter(df['price'],df['area'])
plt.title("Price vs Square Feet")
# Out:
# Text(0.5, 1.0, 'Price vs Square Feet')

# %%
df['bedrooms'].value_counts().plot(kind='bar')
plt.title('number of Bedroom')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(df['bedrooms'],df['price'])
plt.title("Bedroom and Price ")
plt.xlabel("Bedrooms")
plt.ylabel("Price")
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
df['bathrooms'].value_counts().plot(kind='bar')
plt.title('number of Bathroom')
plt.xlabel('Bathrooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(df['bathrooms'],df['price'])
plt.title("Bathroom and Price ")
plt.xlabel("Bathrooms")
plt.ylabel("Price")
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
df['stories'].value_counts().plot(kind='bar')
plt.title('number of stories')
plt.xlabel('Stories')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(df['stories'],df['price'])
plt.title("Stories and Price ")
plt.xlabel("Stories")
plt.ylabel("Price")
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(df['price'],df['mainroad'])
plt.title("Price vs Location of the area")
# Out:
# Text(0.5, 1.0, 'Price vs Location of the area')

# %%
plt.scatter(df['price'],df['guestroom'])
plt.title("Price vs Having guestroom")
# Out:
# Text(0.5, 1.0, 'Price vs Having guestroom')

# %%
plt.scatter(df['price'],df['basement'])
plt.title("Price vs Having basement")
# Out:
# Text(0.5, 1.0, 'Price vs Having basement')

# %%
plt.scatter(df['price'],df['hotwaterheating'])
plt.title("Price vs Having hotwaterheating")
# Out:
# Text(0.5, 1.0, 'Price vs Having hotwaterheating')

# %%
plt.scatter(df['price'],df['airconditioning'])
plt.title("Price vs Having airconditioning")
# Out:
# Text(0.5, 1.0, 'Price vs Having airconditioning')

# %%
df['parking'].value_counts().plot(kind='bar')
plt.title('number of Parking')
plt.xlabel('Parking')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(df['parking'],df['price'])
plt.title("Parking and Price ")
plt.xlabel("Parking")
plt.ylabel("Price")
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(df['price'],df['prefarea'])
plt.title("Price vs Having prefarea")
# Out:
# Text(0.5, 1.0, 'Price vs Having prefarea')

# %%
plt.scatter(df['price'],df['furnishingstatus'])
plt.title("Price vs Furnishing Status")
# Out:
# Text(0.5, 1.0, 'Price vs Furnishing Status')

# %%
plt.scatter((df['area']+df['furnishingstatus']),df['price'])
plt.title("The relationship between area, furnishing status and price")

# %%
train1 = df.drop(['price'],axis=1)
train1.head();

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
labels = df['price']
train1 = df.drop(['price'],axis=1)
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(train1 , labels , test_size = 0.10,random_state =2)
reg.fit(x_train,y_train)
reg.score(x_test,y_test)
# Out:
# 0.6806426338110982

# %%
from sklearn import ensemble

clf = ensemble.GradientBoostingRegressor(n_estimators = 400, max_depth = 5, min_samples_split = 2,
          learning_rate = 0.1, loss = 'squared_error')
clf.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=5, n_estimators=400)

# %%
clf.score(x_test,y_test)
# Out:
# 0.5233674548954742

# %%
params = {'n_estimators': 400, 'max_depth': 5, 'min_samples_split': 2, 'learning_rate': 0.1}
clf = ensemble.GradientBoostingRegressor(**params, loss='squared_error')
t_sc = np.zeros((params['n_estimators']),dtype=np.float64)
y_pred = reg.predict(x_test)
clf.fit(x_train, y_train)

for i,y_pred in enumerate(clf.staged_predict(x_test)):
    t_sc[i]=clf.loss_(y_test,y_pred)
testsc = np.arange((params['n_estimators']))+1
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(testsc,clf.train_score_,'b-',label= 'Set dev train')
plt.plot(testsc,t_sc,'r-',label = 'set dev test')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/deprecation.py:101: FutureWarning: Attribute `loss_` was deprecated in version 1.1 and will be removed in 1.3.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA
pca = PCA()
pca.fit_transform(scale(train1))
# Out:
# array([[ 3.50218652, -1.14956521, -0.98041808, ...,  0.16628004,
#         -0.63415932, -0.3513553 ],
#        [ 5.32702803, -3.43195731, -0.63369168, ...,  2.49306324,
#         -1.02389313,  0.38095466],
#        [ 2.41291549,  1.17589854, -0.69908089, ...,  0.77217882,
#         -0.07361377,  1.21581907],
#        ...,
#        [-2.31292068,  0.29818905, -0.65174165, ...,  0.58019909,
#         -0.01867847, -0.30370879],
#        [-1.97867183, -0.59129201,  0.92632868, ..., -0.45690876,
#         -0.24170775, -0.36400875],
#        [-1.45212204, -0.73887458, -0.22020587, ..., -0.29055272,
#          0.19814706, -0.1171619 ]])

# %%
#To make predictions
# Load new data to make predictions on
new_data = pd.read_csv("new_house_data.csv")

# Apply the same mappings as before
new_data['mainroad'] = new_data['mainroad'].map(mapping).astype(float)
new_data['guestroom'] = new_data['guestroom'].map(mapping).astype(float)
new_data['basement'] = new_data['basement'].map(mapping).astype(float)
new_data['hotwaterheating'] = new_data['hotwaterheating'].map(mapping).astype(float)
new_data['airconditioning'] = new_data['airconditioning'].map(mapping).astype(float)
new_data['prefarea'] = new_data['prefarea'].map(mapping).astype(float)
new_data['furnishingstatus'] = new_data['furnishingstatus'].map(mappingf).astype(float)

# Make predictions
predictions = clf.predict(new_data)

# Print the predictions
print(predictions)
